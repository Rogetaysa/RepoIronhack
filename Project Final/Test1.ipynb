# %%
# Import your libraries:

# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings                                              
from sklearn.exceptions import DataConversionWarning          
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

# %%
df = pd.read_xml('/Users/gabrielrogetdeaysa/Documents/Salud Ironhack/apple_health_export/exportació.xml')
df.head()
# Out:
#                        value HKCharacteristicTypeIdentifierDateOfBirth  \
# 0  2024-11-18 18:19:59 +0100                                      None
# 1                       None                                1992-08-11
# 2                       23.1                                      None
# 3                         23                                      None
# 4                       23.2                                      None
#
#   HKCharacteristicTypeIdentifierBiologicalSex  \
# 0                                        None
# 1                         HKBiologicalSexMale
# 2                                        None
# 3                                        None
# 4                                        None
#
#   HKCharacteristicTypeIdentifierBloodType  \
# 0                                    None
# 1                    HKBloodTypeONegative
# 2                                    None
# 3                                    None
# 4                                    None
#
#   HKCharacteristicTypeIdentifierFitzpatrickSkinType  \
# 0                                              None
# 1                       HKFitzpatrickSkinTypeNotSet
# 2                                              None
# 3                                              None
# 4                                              None
#
#   HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse  \
# 0                                               None
# 1                                                Cap
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                     type sourceName sourceVersion   unit  ...  \
# 0                                   None       None          None   None  ...
# 1                                   None       None          None   None  ...
# 2  HKQuantityTypeIdentifierBodyMassIndex    Fitdays             2  count  ...
# 3  HKQuantityTypeIdentifierBodyMassIndex    Fitdays             2  count  ...
# 4  HKQuantityTypeIdentifierBodyMassIndex    Fitdays             2  count  ...
#
#   activeEnergyBurned activeEnergyBurnedGoal activeEnergyBurnedUnit  \
# 0                NaN                    NaN                   None
# 1                NaN                    NaN                   None
# 2                NaN                    NaN                   None
# 3                NaN                    NaN                   None
# 4                NaN                    NaN                   None
#
#    appleMoveTime appleMoveTimeGoal appleExerciseTime  appleExerciseTimeGoal  \
# 0            NaN               NaN               NaN                    NaN
# 1            NaN               NaN               NaN                    NaN
# 2            NaN               NaN               NaN                    NaN
# 3            NaN               NaN               NaN                    NaN
# 4            NaN               NaN               NaN                    NaN
#
#   appleStandHours  appleStandHoursGoal HeartRateVariabilityMetadataList
# 0             NaN                  NaN                             None
# 1             NaN                  NaN                             None
# 2             NaN                  NaN                             None
# 3             NaN                  NaN                             None
# 4             NaN                  NaN                             None
#
# [5 rows x 33 columns]
