# %% [markdown]
# # Antes de empezar:
#
#     Lee el archivo README.md
#     Comenta todo lo que puedas y utiliza los recursos (archivo README.md)
#     ¡Feliz aprendizaje!

# %% [markdown]
# En este ejercicio, generaremos números aleatorios a partir de las disribuciones continuas que aprendimos en la lección. Hay dos formas de generar números aleatorios:
#
# 1. Usando la librería numpy
# 1. Usando la librería Scipy
#
# Utiliza cualquiera de las dos librerías o ambas en este ejercicio.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Normalizer
from datetime import datetime
from scipy.optimize import fmin
from scipy.stats import norm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 12
#      10 from scipy.optimize import fmin
#      11 from scipy.stats import norm
# ---> 12 from spicy.stats import expon
#
# ModuleNotFoundError: No module named 'spicy'

# %% [markdown]
# ## Distribución Uniforme
#
# Para generar números aleatorios uniformes entre dos valores dados usando scipy, podemos usar el siguiente código o el código que hemos
# discutido en clase:

# %%
# your code here

# %% [markdown]
# **Tarea:**
#
# 1. Basándote en el código anterior, escribe una función que genere números aleatorios uniformemente distribuidos. Hay varios requisitos para tu función:
#     * Debe aceptar 3 parámetros:
#         * `bottom` - el límite inferior de los números generados
#         * `ceiling` - el límite superior de los números generados
#         * `count` - cuántos números generar
#     * Debe devolver una matriz de números aleatorios distribuidos uniformemente
#
# 2. Llama a tu función con 2 conjuntos de parámetros a continuación:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 3. Traza las distribuciones uniformes generadas anteriormente utilizando histogramas, donde el eje x es el valor y el eje y es el recuento. Que el número de intervalos del histograma sea 10.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
# your code here
def generar_uniforme(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %%
# your code here

uniforme1 = generar_uniforme(10,15,100)
uniforme2 = generar_uniforme(10,60,1000)

plt.figure(figsize=(12,5))

# %%
# your code here
y_max= max(np.histogram(uniforme1, bins=10)[0].max(),
          np.histogram(uniforme2, bins=10)[0].max())

plt.subplot(1,2,1)
plt.hist(uniforme1, bins=10, edgecolor="black")
plt.ylim(0,y_max)
plt.title("Ejemplo1")

plt.subplot(1,2,2)
plt.hist(uniforme2, bins=10, edgecolor="black")
plt.ylim(0,y_max)
plt.title("Ejemplo2")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Distribución Normal
#
# 1. De la misma manera en el reto de Distribución Uniforme, escriba una función que genere números aleatorios distribuidos normalmente.
# 1. Genera 1.000 números distribuidos normalmente con media de 10 y desviación típica de 1
# 1. Genera 1.000 números distribuidos normalmente con una media de 10 y una desviación típica de 50
# 2. Representa gráficamente las distribuciones de los datos generados.
#
# Resultado esperado:
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm

# %%
# your code here
def generar_normal(media, desviacion, count):
    return np.random.normal(media, desviacion, count)

normal1= generar_normal(10,1, 1000)
normal2= generar_normal(10,50, 1000)

plt.figure(figsize=(12,5))

# %%
# your code here
y_max= max(np.histogram(normal1, bins=50)[0].max(),
          np.histogram(normal2, bins=50)[0].max())

plt.subplot(1,2,1)
plt.hist(normal1, bins=50)
plt.ylim(0,y_max)
plt.title("Normal 1")

plt.subplot(1,2,2)
plt.hist(normal2, bins=50)
plt.ylim(0,y_max)
plt.title("Normal 2")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# your code here

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here

# %% [markdown]
# ## Distribución Normal de Datos Reales
#
# En este reto vamos a echar un vistazo a los datos reales. Utilizaremos el archivo vehicles.csv para este ejercicio

# %%
# your code here
vehicles = pd.read_csv('/Users/gabrielrogetdeaysa/Library/CloudStorage/GoogleDrive-rogetaysa@gmail.com/La meva unitat/IronhackGD/RepoIronhack/Entregas/40.2 lab-continuous-probability-distributions-es-main/your-code/vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# Primero importa vehicles.csv.
# A continuación, traza los histogramas de las siguientes variables:
#
# 1. Barriles de combustible/año

# %%
# your code here
fuel_year = vehicles.groupby("Year")["Fuel Barrels/Year"].sum()

plt.figure(figsize=(10,5))
plt.plot(fuel_year.index, fuel_year.values, marker=".", linestyle ="-", color="b")
plt.xlabel('Año')
plt.ylabel('Suma barriles')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# your code here
plt.figure(figsize=(10,5))

plt.hist(vehicles["Fuel Barrels/Year"], bins=50)
plt.xlabel("Fuel Barrels al año")
plt.ylabel("Barriles")
plt.grid(True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 2. Emisiones de CO2 Gramos/Milla

# %%
# your code here
plt.figure(figsize=(10,5))

plt.hist(vehicles["CO2 Emission Grams/Mile"], bins=50)
plt.xlabel("CO2 Emission Grams/Mile")
plt.ylabel("Cantidad")
plt.grid(True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# your code here

# %% [markdown]
# 3. MPG combinado

# %%
# your code here
plt.figure(figsize=(10,5))

plt.hist(vehicles["Combined MPG"], bins=50)
plt.xlabel("Combined MPG")
plt.ylabel("Cantidad")
plt.grid(True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ¿Cuál o cuáles de las variables tienen una distribución casi normal? ¿Cómo lo sabes?

# %%
# your code here
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.hist(vehicles["Fuel Barrels/Year"], bins=50)
plt.xlabel("Fuel Barrels al año")
plt.ylabel("Cantidad")
plt.grid(True)

plt.subplot(1,3,2)
plt.hist(vehicles["CO2 Emission Grams/Mile"], bins=50)
plt.xlabel("CO2 Emission Grams/Mile")
plt.grid(True)

plt.subplot(1,3,3)
plt.hist(vehicles["Combined MPG"], bins=50)
plt.xlabel("Combined MPG")
plt.grid(True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Ninguno de ellos está normalmente ditribuido.

# %% [markdown]
# ## Distribución Exponencial

# %% [markdown]
# 1. Utilizando `numpy.random.exponential`, crea una función que devuelva una lista de números distribuidos exponencialmente con la media de 10.
#
# 1. Utiliza la función para generar dos secuencias de números de tamaño 10 y 100.
#
# 1. 2. Traza las distribuciones como histogramas con el número de bins como 100.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
# your code here
def generar_exponencial(media, count):
    return np.random.exponential(media, count)

exponencial10= generar_exponencial(10,10)
exponencial100= generar_exponencial(10,100)

plt.figure(figsize=(12,5))

y_max= max(np.histogram(exponencial10, bins=100)[0].max(),
          np.histogram(exponencial100, bins=100)[0].max())

plt.subplot(1,2,1)
plt.hist(exponencial10, bins=100)
plt.ylim(0,y_max)
plt.title("Exponencial 10")

plt.subplot(1,2,2)
plt.hist(exponencial100, bins=100)
plt.ylim(0,y_max)
plt.title("Exponencial 100")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ¿En qué se diferencian ambas distribuciones?

# %% [markdown]
# La media cambia, por lo que la distribución también cambia.

# %% [markdown]
# ## Distribución Exponencial de datos reales
#
# Supongamos que el tiempo que uno pasa en un banco se distribuye exponencialmente con media de 10 minutos (es decir, λ = 1/10). ¿Cuál es la probabilidad de que un cliente pase menos de quince minutos en el banco?
#
# Escribe un código en python para resolver este problema

# %%
# your code here
#from spicy.stats import expon 
media=10
param_lambda = 1/ media

prob_15 = round(100*(1 - math.exp(-param_lambda*15)),2)
print("Probabilitat passar menys de 15 min:", prob_15, "%")
# Out:
# Probabilitat passar menys de 15 min: 77.69 %

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# ¿Cuál es la probabilidad de que el cliente pase más de 15 minutos?

# %%
# your code here
prob_15 = round(100*( math.exp(-param_lambda*15)),2)
print("Probabilitat passar més de 15 min:", prob_15, "%")
# Out:
# Probabilitat passar més de 15 min: 22.31 %
